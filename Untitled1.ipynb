# %%
import pandas as pd

# %%
data = pd.read_csv("Accident_States.csv")
data.head()
# Out:
#           Unnamed: 0                                         Unnamed: 1  \
# 0         States/UTs  State/UT-Wise Total Number of Persons Injured ...
# 1     Andhra Pradesh                                              52157
# 2  Arunachal Pradesh                                                530
# 3              Assam                                               5522
# 4              Bihar                                               7113
#
#                                           Unnamed: 2  \
# 0  State/UT-Wise Total Number of Persons Injured ...
# 1                                              53928
# 2                                                491
# 3                                               7579
# 4                                               8106
#
#                                           Unnamed: 3  \
# 0  State/UT-Wise Total Number of Persons Injured ...
# 1                                              55583
# ...

# %%
data=data.applymap(lambda x:x.strip() if isinstance(x,str) else x)
data
# Out:
#                      Unnamed: 0  \
# 0                    States/UTs
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                         Bihar
# 5                  Chhattisgarh
# 6                           Goa
# 7                       Gujarat
# 8                       Haryana
# 9              Himachal Pradesh
# 10            Jammu and Kashmir
# 11                    Jharkhand
# 12                    Karnataka
# 13                       Kerala
# 14               Madhya Pradesh
# 15                  Maharashtra
# 16                      Manipur
# 17                    Meghalaya
# 18                      Mizoram
# 19                     Nagaland
# 20                       Odisha
# 21                       Punjab
# 22                    Rajasthan
# 23                       Sikkim
# 24                   Tamil Nadu
# 25                    Telangana
# 26                      Tripura
# 27                  Uttarakhand
# ...

# %%
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]
data
# Out:
#     KIlled due to Over Speed  Accidents due to Alcohal and drugs
# 0                     2008.0                              2008.0
# 1                     7471.0                              1591.0
# 2                       32.0                                25.0
# 3                      843.0                               530.0
# 4                     1008.0                              1944.0
# 5                     1347.0                               855.0
# 6                      271.0                                42.0
# 7                     4373.0                               540.0
# 8                     2580.0                               427.0
# 9                      388.0                                34.0
# 10                     603.0                               378.0
# 11                     633.0                               725.0
# 12                    5678.0                               513.0
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'KIlled due to Over Speed', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Accidents due to Alcohal and drugs', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
data1 = pd.read_csv("Accident_Cities.csv")
data1.head()
# Out:
#        Name of City  Total number of Fatal Accidents - 2011  \
# 0              Agra                                   336.0
# 1         Ahmedabad                                   222.0
# 2  Asansol-Durgapur                                   229.0
# 3        Aurangabad                                   161.0
# 4         Bengaluru                                   689.0
#
#    All Accidents - 2011  Persons Killed - 2011  Persons Injured - 2011  \
# 0                1299.0                  632.0                  1046.0
# 1                2020.0                  227.0                  2036.0
# 2                 368.0                  230.0                   185.0
# 3                 719.0                  173.0                   744.0
# 4                6031.0                  720.0                  4952.0
#
#    Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 0                                   381.0                 922.0
# ...

# %%
data1.columns
# Out:
# Index(['Name of City', 'Total number of Fatal Accidents - 2011',
#        'All Accidents - 2011', 'Persons Killed - 2011',
#        'Persons Injured - 2011', 'Total number of Fatal Accidents - 2012',
#        'All Accidents - 2012', 'Persons Killed - 2012',
#        'Persons Injured - 2012', 'Fatal Accidents - 2013',
#        'Total Accidents - 2013', 'Killed - 2013', 'Injured - 2013',
#        'Severity - 2013', 'Fatal Accidents - 2014',
#        'Greviously Injured Accidents - 2014', 'Minor Accidents - 2014',
#        'Non-Injurey Accidents - 2014', 'Total Accidents - 2014',
#        'Killed - 2014', 'Injured - 2014', 'Severity - 2014',
#        'Fatal Accidents - 2015', 'Greviously Injured Accidents - 2015',
#        'Minor Accidents - 2015', 'Non-Injurey Accidents - 2015',
#        'Total Accidents - 2015', 'Killed - 2015', 'Injured - 2015',
#        'Severity - 2015'],
#       dtype='object')

# %%
#3 Cities where maximum number of people injured from 2011 to 2015.
injury = data1[["Name of City","Persons Injured - 2011","Persons Injured - 2012","Injured - 2014","Injured - 2015"]]
injury.sort_values('Name of City', ascending=False)
injury.head(3)
# Out:
#        Name of City  Persons Injured - 2011  Persons Injured - 2012  \
# 0              Agra                  1046.0                   675.0
# 1         Ahmedabad                  2036.0                  1845.0
# 2  Asansol-Durgapur                   185.0                   315.0
#
#    Injured - 2014  Injured - 2015
# 0           747.0           650.0
# 1          1597.0          1722.0
# 2           284.0           220.0

# %%
#5 major states which has more deaths due to over speed from 2010 to 2015.
overspeed= data[["States/UTs","KIlled due to Over Speed"]]
overspeed.sort_values('States/UTs', ascending=False)
overspeed.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-bbb262bd51e8> in <module>()
#       1 #5 major states which has more deaths due to over speed from 2010 to 2015.
# ----> 2 overspeed= data[["States/UTs","KIlled due to Over Speed"]]
#       3 overspeed.sort_values('States/UTs', ascending=False)
#       4 overspeed.head(5)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
# ...

# %%
#average deaths for any given state from year 2012 to 2016 due to over speed
data[data["KIlled due to Over Speed"].mean() and data["States/UTs"]=="Andhra Pradesh"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'States/UTs'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-26dd6465b3fe> in <module>()
# ...

# %%
data1[["Name of City","Total number of Fatal Accidents - 2011","Total number of Fatal Accidents - 2012","Fatal Accidents - 2013","Fatal Accidents - 2014","Fatal Accidents - 2015"]][data1['Name of City']=='Delhi']
# Out:
#   Name of City  Total number of Fatal Accidents - 2011  \
# 7        Delhi                                  2007.0
#
#    Total number of Fatal Accidents - 2012  Fatal Accidents - 2013  \
# 7                                  1822.0                  1778.0
#
#    Fatal Accidents - 2014  Fatal Accidents - 2015
# 7                  1629.0                  1582.0

# %%
data1[["Name of City","Total number of Fatal Accidents - 2011","Total number of Fatal Accidents - 2012","Fatal Accidents - 2013","Fatal Accidents - 2014","Fatal Accidents - 2015"]][data1['Name of City']=='Bengaluru']
# Out:
#   Name of City  Total number of Fatal Accidents - 2011  \
# 4    Bengaluru                                   689.0
#
#    Total number of Fatal Accidents - 2012  Fatal Accidents - 2013  \
# 4                                   707.0                   733.0
#
#    Fatal Accidents - 2014  Fatal Accidents - 2015
# 4                   703.0                   708.0

# %%
data1[["Name of City","Total number of Fatal Accidents - 2011","Total number of Fatal Accidents - 2012","Fatal Accidents - 2013","Fatal Accidents - 2014","Fatal Accidents - 2015"]][data1['Name of City']=='Mumbai']
# Out:
#    Name of City  Total number of Fatal Accidents - 2011  \
# 27       Mumbai                                   539.0
#
#     Total number of Fatal Accidents - 2012  Fatal Accidents - 2013  \
# 27                                   471.0                   481.0
#
#     Fatal Accidents - 2014  Fatal Accidents - 2015
# 27                   512.0                   586.0

# %%
data1[["Name of City","Total number of Fatal Accidents - 2011","Total number of Fatal Accidents - 2012","Fatal Accidents - 2013","Fatal Accidents - 2014","Fatal Accidents - 2015"]][data1['Name of City']=='Kolkata']
# Out:
#    Name of City  Total number of Fatal Accidents - 2011  \
# 19      Kolkata                                   396.0
#
#     Total number of Fatal Accidents - 2012  Fatal Accidents - 2013  \
# 19                                   471.0                   420.0
#
#     Fatal Accidents - 2014  Fatal Accidents - 2015
# 19                   431.0                   412.0

# %%
data1[["Name of City","Total number of Fatal Accidents - 2011","Total number of Fatal Accidents - 2012","Fatal Accidents - 2013","Fatal Accidents - 2014","Fatal Accidents - 2015"]][data1['Name of City']=='Lucknow']
# Out:
#    Name of City  Total number of Fatal Accidents - 2011  \
# 23      Lucknow                                   493.0
#
#     Total number of Fatal Accidents - 2012  Fatal Accidents - 2013  \
# 23                                   474.0                   458.0
#
#     Fatal Accidents - 2014  Fatal Accidents - 2015
# 23                   515.0                   483.0

# %%
# 5 major cities which has maximum deaths from 2011 to 2015
death= data1[["Name of City","Persons Killed - 2011","Persons Killed - 2012","Killed - 2013","Killed - 2014","Killed - 2015"]]
death.sort_values('Name of City', ascending=False)
death.head(5)
# Out:
#        Name of City  Persons Killed - 2011  Persons Killed - 2012  \
# 0              Agra                  632.0                  427.0
# 1         Ahmedabad                  227.0                  251.0
# 2  Asansol-Durgapur                  230.0                  224.0
# 3        Aurangabad                  173.0                  192.0
# 4         Bengaluru                  720.0                  725.0
#
#    Killed - 2013  Killed - 2014  Killed - 2015
# 0          502.0          503.0          474.0
# 1          230.0          262.0          328.0
# 2          218.0          210.0          210.0
# 3          160.0          170.0          170.0
# 4          752.0          729.0          713.0

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [Persons Killed - 2011 	Persons Killed - 2012 	Killed - 2013 	Killed - 2014 	Killed - 2015]
x_pos = np.arange(len('Name of City'))
y = ['Agra','Ahmedabad','Asansol-Durgapur','Aurangabad','Bengaluru']

plt.barh(x_pos, performance, align='center')
plt.yticks(x_pos, objects)
plt.xlabel('Usage')
plt.title('Programming Language Usage')

plt.show()
